# %%
import cufflinks
import cufflinks as cf
cf.set_config_file(offline=True)
import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cufflinks.datagen.box()
# Out:
#        ZNK.SZ     LYD.DB    JYV.YM     NZX.GY     EFA.PU
# 0    5.383207   6.689883  5.085557   5.877483   6.734775
# 1    1.546679   0.067955  0.534785   1.048798   0.105832
# 2    7.730086   3.617768  2.973345   4.279101  10.978224
# 3    8.492403   3.737729  2.105478  11.288842   1.123927
# 4    8.533755   6.696211  9.503454   6.046037  12.210837
# ..        ...        ...       ...        ...        ...
# 95   4.051180   1.745398  0.840177   5.217239   0.679319
# 96   4.853079  10.573224  5.378003  10.185149   6.279455
# 97   8.484288   2.476688  9.855582   7.245945   8.868270
# 98   7.829953  11.317999  2.908225   3.395613   6.166201
# 99  11.075432   1.353132  9.618540   8.137401   9.550629
#
# [100 rows x 5 columns]

# %%
df=cf.datagen.ohlc()
qf=cf.QuantFig(df,title='First Quant Figure',legend='top',name='GS')
qf.add_bollinger_bands()
qf.iplot()

# %%
# !pip install chart_studio

# %%
df_stock = px.data.stocks()

# %%
df_stock.head()
# Out:
#          date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0  2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2  2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3  2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4  2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708

# %%
df_stock.iplot(x="GOOG")
