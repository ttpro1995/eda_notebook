# %%
import numpy as np

# %%
x = np.random.randn(5000)

# %%
np.histogram(x)
# Out:
# (array([   4,   41,  229,  798, 1356, 1420,  820,  267,   62,    3]),
#  array([-3.88756245, -3.11651583, -2.3454692 , -1.57442258, -0.80337595,
#         -0.03232932,  0.7387173 ,  1.50976393,  2.28081055,  3.05185718,
#          3.8229038 ]))

# %%
dt = np.histogram(x)

# %%
dt[0]
# Out:
# array([   4,   41,  229,  798, 1356, 1420,  820,  267,   62,    3])

# %%
dt[1]
# Out:
# array([-3.88756245, -3.11651583, -2.3454692 , -1.57442258, -0.80337595,
#        -0.03232932,  0.7387173 ,  1.50976393,  2.28081055,  3.05185718,
#         3.8229038 ])

# %%
import plotly.express as px

# %%
px.bar(dt[0])

# %%
px.histogram(x)
